# %%
## importing libraries

# reading data
import pandas as pd
import geopandas as gpd
import numpy as np
import fiona
import osmnx as ox

# plots/charts
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px
import plotly.io as pio
    # pio.templates.default = "ggplot2"
    # options: seaborn, simple_white, plotly, plotly_white, plotly_dark
    # presentation, xgridoff, ygridoff, gridon, none

# maps
import contextily as ctx
import folium
import matplotlib.patches as mpatches #custom legends
#import collections
# Out:
# ERROR 1: PROJ: proj_create_from_database: Open of /opt/conda/share/proj failed

# %%
CESdata = gpd.read_file('calenviroscreen40shpf2021shp.zip')

# %%
CESdata.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 8035 entries, 0 to 8034
# Data columns (total 67 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Tract       8035 non-null   float64
#  1   ZIP         8035 non-null   int64
#  2   County      8035 non-null   object
#  3   ApproxLoc   8035 non-null   object
#  4   TotPop19    8035 non-null   int64
#  5   CIscore     8035 non-null   float64
#  6   CIscoreP    8035 non-null   float64
#  7   Ozone       8035 non-null   float64
#  8   OzoneP      8035 non-null   float64
#  9   PM2_5       8035 non-null   float64
#  10  PM2_5_P     8035 non-null   float64
#  11  DieselPM    8035 non-null   float64
#  12  DieselPM_P  8035 non-null   float64
#  13  Pesticide   8035 non-null   float64
#  14  PesticideP  8035 non-null   float64
#  15  Tox_Rel     8035 non-null   float64
#  16  Tox_Rel_P   8035 non-null   float64
#  17  Traffic     8035 non-null   float64
#  18  TrafficP    8035 non-null   float64
#  19  DrinkWat    8035 non-null   float64
#  20  DrinkWatP   8035 non-null   float64
#  21  Lead        8035 non-null   float64
#  22  Lead_P      8035 non-null   float64
#  23  Cleanup     8035 non-null   float64
#  24  CleanupP    8035 non-null   float64
#  25  GWThreat    8035 non-null   float64
#  26  GWThreatP   8035 non-null   float64
#  27  HazWaste    8035 non-null   float64
#  28  HazWasteP   8035 non-null   float64
#  29  ImpWatBod   8035 non-null   float64
#  30  ImpWatBodP  8035 non-null   float64
#  31  SolWaste    8035 non-null   float64
#  32  SolWasteP   8035 non-null   float64
#  33  PollBurd    8035 non-null   float64
#  34  PolBurdSc   8035 non-null   float64
#  35  PolBurdP    8035 non-null   float64
#  36  Asthma      8035 non-null   float64
#  37  AsthmaP     8035 non-null   float64
#  38  LowBirtWt   8035 non-null   float64
#  39  LowBirWP    8035 non-null   float64
#  40  Cardiovas   8035 non-null   float64
#  41  CardiovasP  8035 non-null   float64
#  42  Educatn     8035 non-null   float64
#  43  EducatP     8035 non-null   float64
#  44  Ling_Isol   8035 non-null   float64
#  45  Ling_IsolP  8035 non-null   float64
#  46  Poverty     8035 non-null   float64
#  47  PovertyP    8035 non-null   float64
#  48  Unempl      8035 non-null   float64
#  49  UnemplP     8035 non-null   float64
#  50  HousBurd    8035 non-null   float64
#  51  HousBurdP   8035 non-null   float64
#  52  PopChar     8035 non-null   float64
#  53  PopCharSc   8035 non-null   float64
#  54  PopCharP    8035 non-null   float64
#  55  Child_10    8035 non-null   float64
#  56  Pop_10_64   8035 non-null   float64
#  57  Elderly65   8035 non-null   float64
#  58  Hispanic    8035 non-null   float64
#  59  White       8035 non-null   float64
#  60  AfricanAm   8035 non-null   float64
#  61  NativeAm    8035 non-null   float64
#  62  OtherMult   8035 non-null   float64
#  63  Shape_Leng  8035 non-null   float64
#  64  Shape_Area  8035 non-null   float64
#  65  AAPI        8035 non-null   float64
#  66  geometry    8035 non-null   geometry
# dtypes: float64(62), geometry(1), int64(2), object(2)
# memory usage: 4.1+ MB

# %%
CESdata['Tract'] = CESdata['Tract'].astype(np.str)
CESdata['Tract'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 8035 entries, 0 to 8034
# Series name: Tract
# Non-Null Count  Dtype
# --------------  -----
# 8035 non-null   object
# dtypes: object(1)
# memory usage: 62.9+ KB
# /tmp/ipykernel_215/1589585780.py:1: DeprecationWarning: `np.str` is a deprecated alias for the builtin `str`. To silence this warning, use `str` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.str_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   CESdata['Tract'] = CESdata['Tract'].astype(np.str)

# %%
CESdata['FIPS'] = '0'+CESdata['Tract']
CESdata.sample()
# Out:
#              Tract    ZIP       County ApproxLoc  TotPop19    CIscore  \
# 5890  6037533806.0  90201  Los Angeles      Bell      3794  71.997616
#
#        CIscoreP     Ozone   OzoneP      PM2_5  ...  Hispanic   White  \
# 5890  99.369642  0.046325  46.9944  12.043519  ...   94.8867  0.9489
#
#       AfricanAm  NativeAm  OtherMult   Shape_Leng    Shape_Area    AAPI  \
# 5890     3.5319       0.0        0.0  8703.431017  1.233838e+06  0.6326
#
#                                                geometry           FIPS
# 5890  POLYGON ((169389.434 -447870.222, 169536.070 -...  06037533806.0
#
# [1 rows x 68 columns]

# %%
CESdata['County'].value_counts()
# Out:
# Los Angeles        2343
# San Diego           627
# Orange              582
# Riverside           453
# Santa Clara         372
# San Bernardino      369
# Alameda             360
# Sacramento          317
# Contra Costa        207
# Fresno              199
# San Francisco       195
# Ventura             173
# San Mateo           157
# Kern                151
# San Joaquin         139
# Sonoma               99
# Solano               96
# Stanislaus           94
# Monterey             93
# Santa Barbara        89
# Placer               84
# Tulare               78
# Marin                55
# San Luis Obispo      53
# Santa Cruz           52
# Butte                51
# Merced               49
# Shasta               48
# El Dorado            42
# Yolo                 41
# Napa                 40
# Imperial             31
# Humboldt             30
# Kings                27
# Madera               23
# Sutter               21
# Mendocino            20
# Nevada               20
# Lake                 15
# Yuba                 14
# Siskiyou             14
# San Benito           11
# Tuolumne             11
# Tehama               11
# Calaveras            10
# Amador                9
# Lassen                9
# Plumas                7
# Del Norte             7
# Inyo                  6
# Mariposa              6
# Glenn                 6
# Colusa                5
# Trinity               5
# Modoc                 4
# Mono                  3
# Alpine                1
# Sierra                1
# Name: County, dtype: int64

# %%
Kern_env = CESdata[CESdata.County == 'Kern']
Kern_env.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# Int64Index: 151 entries, 1402 to 1552
# Data columns (total 68 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   
# 1547  38.237416  72.503782  0.062365  88.699440  12.341031  ...   38.7458
#
#         White  AfricanAm  NativeAm  OtherMult    Shape_Leng    Shape_Area  \
# 1428  76.5204     0.0000    0.0000     2.2765  11984.663128  8.309757e+06
# 1407  62.6693     6.1214    0.0000     4.5158  81426.203702  2.868042e+08
# 1547  59.2752     0.5484    0.5722     0.8584  10872.675453  5.448001e+06
#
#         AAPI                                           geometry           FIPS
# 1428  0.0000  POLYGON ((138948.760 -316773.789, 139270.644 -...  06029006003.0
# 1407  4.3151  POLYGON ((213671.586 -243974.456, 213748.482 -...  06029005300.0
# 1547  0.0000  POLYGON ((47099.870 -319781.365, 47306.314 -31...  06029003600.0
#
# [3 rows x 68 columns]

# %%
Kern_env = Kern_env[['TotPop19', 'ApproxLoc','Tract','FIPS','Hispanic','White','AfricanAm','NativeAm','OtherMult','Asthma','AsthmaP','Cardiovas','CardiovasP','LowBirtWt','LowBirWP','Shape_Leng','Shape_Area','geometry']]
Kern_env.head()
# Out:
#       TotPop19    ApproxLoc         Tract           FIPS  Hispanic    White  \
# 1402      5613  Bakersfield  6029001802.0  06029001802.0   32.7276  49.2250
# 1403      2923  Bakersfield  6029006201.0  06029006201.0   75.8809  21.8953
# 1404      1963      Shafter  6029003900.0  06029003900.0   56.0876  31.5843
# 1405      3739  Bakersfield  6029001700.0  06029001700.0   28.6975  62.2626
# 1406      4300      Oildale  6029000400.0  06029000400.0   20.4186  69.7442
#
#       AfricanAm  NativeAm  OtherMult  Asthma    AsthmaP  Cardiovas  \
# 1402     8.4447    0.0000     4.4896   81.79  86.453141      17.62
# 1403     0.0000    0.0000     1.9158   77.48  83.599202      21.69
# 1404     8.8640    1.0698     2.3434   63.74  73.005982      18.51
# 1405     3.4234    0.0000     3.3699  155.81  99.165005      21.11
# 1406     2.6512    0.3721     4.8605   74.68  81.829511      19.40
#
#       CardiovasP  LowBirtWt    LowBirWP    Shape_Leng    Shape_Area  \
# 1402   79.150050       5.42   62.612266  12653.176612  4.995807e+06
# 1403   92.883848       7.77   95.432384  68740.430761  8.921771e+07
# 1404   82.739282    -999.00 -999.000000  76205.507941  2.199447e+08
# 1405   90.839980       6.83   88.093405   8691.608218  3.686952e+06
# 1406   85.568295       6.65   85.771106  11642.813435  3.167584e+06
#
#                                                geometry
# 1402  POLYGON ((85530.318 -294415.802, 85381.055 -29...
# 1403  POLYGON ((101858.136 -298451.555, 101945.102 -...
# 1404  POLYGON ((77627.294 -272886.143, 77777.009 -27...
# 1405  POLYGON ((88522.915 -292249.021, 88531.488 -29...
# 1406  POLYGON ((86144.456 -288916.148, 86197.300 -28...

# %%
Kern_env = Kern_env.to_crs("EPSG:4326")

# %%
fig,ax = plt.subplots(figsize=(12,10))
Kern_env.plot(ax=ax,facecolor='#ccc',edgecolor='white',lw=0.2)
# Out:
# <AxesSubplot: >

# %%
print(Kern_env.shape)
# Out:
# (151, 18)
